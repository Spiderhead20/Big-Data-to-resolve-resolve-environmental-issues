# %%
#Importar modulos
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
#Realizar regresión lineal
temperatureData = pd.read_csv('temperature-anomaly.csv')
#temperatureData
X = temperatureData.iloc[:, 2].values.reshape(-1, 1)
Y = temperatureData.iloc[:, 3].values.reshape(-1, 1)
lr = LinearRegression()
lr.fit(X, Y)
Y_pred = lr.predict(X)

# %%
#Visualizar resultados
plt.scatter(X, Y)
plt.plot(X, Y_pred, color = 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Visualizar matriz de datos
sns.heatmap(temperatureData.corr())

# %%
co2Data = pd.read_csv('co2-concentration-long-term.csv')
X2 = co2Data.iloc[:, 2].values.reshape(-1, 1)
Y2 = co2Data.iloc[:, 3].values.reshape(-1, 1)
lr2 = LinearRegression()
lr2.fit(X2, Y2)
Y_pred2 = lr2.predict(X2)

# %%
plt.scatter(X2, Y2)
plt.plot(X2, Y_pred2, color = 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.heatmap(co2Data.corr())

# %%
climateData = pd.read_csv('future-greenhouse-gas-emission-scenarios.csv')
x3 = climateData.iloc[:, [3,4,5]].values
y3 = climateData.iloc[:, 12].values
climateData.head()
# Out:
#   Entity      Code  Year  1.5C pathways (high)  1.5C pathways (low)  \
# 0  World  OWID_WRL  2010                 49.92                47.28
# 1  World  OWID_WRL  2011                 49.60                46.24
# 2  World  OWID_WRL  2012                 49.28                45.20
# 3  World  OWID_WRL  2013                 48.97                44.16
# 4  World  OWID_WRL  2014                 48.65                43.12
#
#    1.5C pathways (median)  2C pathways (high)  2C pathways (low)  \
# 0                   47.42               50.02              46.69
# 1                   46.69               49.76              46.04
# 2                   45.95               49.50              45.39
# 3                   45.22               49.24              44.75
# 4                   44.48               48.98              44.10
#
#    2C pathways (median)  Current policies (high)  Current policies (low)  \
# 0                 48.10                      NaN                     NaN
# ...

# %%
sns.heatmap(climateData.corr())

# %%
#Dividir los datos
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x3, y3, test_size = 0.2, random_state = 0)

# %%
#Regresion lineal multiple
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Prediccion y resultados
ypred = regressor.predict(x_test)
ypred
# Out:
# array([ 51.462254  ,  69.91052785, 132.42110228, 109.73015582,
#        160.01053258,  96.07438504, 117.71386688, 113.72201135,
#        141.93375266, 159.82944147,  59.80079348,  90.43613437,
#         99.5837949 , 151.65203052,  61.42552236,  75.12752845,
#         87.65105308, 159.58090429, 149.66365548])

# %%
#Calcular coeficientes e interceptores
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [ 1.85471135  2.64633951 -6.80880767]
# 153.31224567451702

# %%
#Calculando el valor de R al cuadrado
from sklearn.metrics import r2_score
r2_score(y_test, ypred)
# Out:
# 0.9848236099922527

# %% [markdown]
# # Modelo de analisis de gases de efecto invernadero
# ## Importación de los datos

# %%
#Importar dataset
greenhouseData = pd.read_csv('greenhouse_gas_inventory_data_data.csv')
greenhouseData.head()
# Out:
#   country_or_area  year          value  \
# 0       Australia  2014  393126.946994
# 1       Australia  2013  396913.936530
# 2       Australia  2012  406462.847704
# 3       Australia  2011  403705.528314
# 4       Australia  2010  406200.993184
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...

# %%
sns.heatmap(greenhouseData.corr())
